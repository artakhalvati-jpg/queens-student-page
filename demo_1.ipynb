# %% [markdown]
# <a href="https://colab.research.google.com/github/artakhalvati-jpg/queens-student-page/blob/main/demo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
not x > 7
# Out:
# True

# %%
string_1 = """yadaydaydaydayda
yaydaydaydaydyadya
ydyaydyaydyaydya
ydaydaydyadya"""
print(string_1)
# Out:
# yadaydaydaydayda
# yaydaydaydaydyadya
# ydyaydyaydyaydya
# ydaydaydyadya

# %%
print(len("waeawoieawoieuawiouewaioueaiowue")) #len returns number of characters in a string
# Out:
# 32

# %%
word = "I am the honoured one"

print(word[7]) #indexing uses [] and includes white space!!! Also it starts at 0
# Out:
# e

# %%
word = "I am the honoured one"
print(word[-7]) #negative index starts from the last letter and works backwars
print(word[0])
print(word[1])
print(word[5])
# Out:
# r
# I
#
# t

# %%
#lets try slicing
word = "Freemaker66"
print(word[0:4])
print(word[4:])
# Out:
# Free
# maker66

# %%
word = "freemaker66"
print(word[2:9:3]) #Splicing works like this: [Start: Stop: Skip]. Also Stop is exlusive so wherever you stop go back 1
# Out:
# ear

# %%
"hello, world!".upper()
# Out:
# 'HELLO, WORLD!'

# %%
"Hellom word".replace("Hello", "far")
# Out:
# 'farm word'

# %%
"   hello world".strip()
# Out:
# 'hello world'

# %%
#can't add strings must comma them
word1 = "Dan has"
word2 = 3
word3 = "apples"
print (word1, word2, word3)
# Out:
# Dan has 3 apples

# %%
nums = [1,2,3,4] #array
target = 10
print(nums[0] + nums[1] + nums[2] + nums[3])
# Out:
# 10

# %%
word = "water"
print(type(word)) #type returns the data type
# Out:
# <class 'str'>
